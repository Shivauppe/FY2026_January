# %%
import numpy as np

# %%
arry = np.array([1,2,3,4])

# %%
arry**4
# Out:
# array([  1,  16,  81, 256])

# %%
arry**2
# Out:
# array([ 1,  4,  9, 16])

# %%
matrix1 = np.zeros([3,4], dtype = int)

# %%
matrix2 = np.ones([3,4], dtype = int)

# %%
matrix1.dot(matrix2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 matrix1.dot(matrix2)
#
# ValueError: shapes (3,4) and (3,4) not aligned: 4 (dim 1) != 3 (dim 0)

# %%
matrix3 = np.ones([4,2], dtype = int)

# %%
matrix1.dot(matrix3)
# Out:
# array([[0, 0],
#        [0, 0],
#        [0, 0]])

# %%
np.random.random([1])
# Out:
# array([0.90687824])

# %%
np.random.randint(9)
# Out:
# 3

# %%
numpu
