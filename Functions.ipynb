# %%
print('hello-world')
# Out:
# hello-world

# %%
len('hello-world')
# Out:
# 11

# %%
type(6)
# Out:
# int

# %%
type('string')
# Out:
# str

# %%
type('boolean')
# Out:
# str

# %%
import math
math.ceil(4.2)
# Out:
# 5

# %%
math.floor(4.7)
# Out:
# 4

# %%
a = math.sqrt(16)
print(a)
# Out:
# 4.0

# %%
def fun1():
    print('This is my first function')
fun1()
# Out:
# This is my first function

# %%
#Iterators
mytuple = ("apple", "banana", "cherry")
myit = iter(mytuple)
print(next(myit))
print(next(myit))
# Out:
# apple
# banana

# %%
#generators
def my_generator():
    yield 1
    yield 2
    yield 3
