# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import warnings

# %%
x = np.random.randn(1000)

# %%
df = pd.DataFrame(x,columns = ['Data'], index = pd.date_range('2025-12-01', periods = 1000))

# %%
df
# Out:
#                 Data
# 2025-12-01 -0.564816
# 2025-12-02  1.110824
# 2025-12-03  0.218240
# 2025-12-04  0.430726
# 2025-12-05  0.085963
# ...              ...
# 2028-08-22 -0.242587
# 2028-08-23  1.991728
# 2028-08-24  1.800263
# 2028-08-25  0.068053
# 2028-08-26 -0.434776
#
# [1000 rows x 1 columns]

# %%
df.plot(figsize = (20,8))
plt.show()

#Most of the values are fluctuating between -3 and 3

# %%
y = np.random.randn(1000)

# %%
#scatter plot:

plt.scatter(x,y)

# %%
m = [1,2,3,4,5]
n = [10,20,80,40,150]

plt.plot(m,n,marker = 'o',color = 'g')
plt.title("Line chart to understand the syntax")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.plot(m,n,marker = '*',color = 'b')
plt.title("Line chart to understand the syntax")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.plot(m,n,marker = 'o',color = 'b',linestyle = '--',linewidth = 4)
plt.title("Line chart to understand the syntax")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.show()

# %%
plt.plot(m,n,marker = 'o',markersize = 15,color = 'violet',linestyle = '--',linewidth = 4)
plt.title("Line chart to understand the syntax")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid()
plt.show()

# %%
x = [1,2,3,4,5]
y1 = [5,1,7,8,2]
y2 = [7,8,3,5,1]

plt.plot(x,y1,marker = 'o',linestyle = '--',linewidth = 4, label = 'Tata motors ')
plt.plot(x,y2,marker = 'o',linestyle = '-',linewidth = 2, label = 'Tata power ')
plt.xlabel('x-axis')
plt.ylabel('y-axis')
plt.legend()
plt.show()

# %%
x1 = np.linspace(0,10,100)
x2 = np.sin(x1)

# %%
plt.plot(x1,np.sin(x1),c = 'g',ls = '-',lw = '4',label = 'sinx')
plt.plot(x1,np.cos(x1),c = 'b',ls = '--',lw = '4',label = 'cosx')
plt.legend()
plt.show()

# %%
plt.figure()
plt.subplot(1,2,1)
plt.plot(x1,np.sin(x1))

plt.subplot(1,2,2)
plt.plot(x1,np.cos(x1),c = 'r')
plt.show()

# %%
plt.figure()
plt.subplot(2,1,1)
plt.plot(x1,np.sin(x1))

plt.subplot(2,1,2)
plt.plot(x1,np.cos(x1),c = 'g')
plt.show()

# %%
plt.plot(x1,np.tan(x1))
plt.show()

# %%
plt.plot(x1,np.sin(x1))
plt.xlim = (1,1)
plt.ylim = (-1,10)

# %%
#histogram

a = np.random.randn(1000)
plt.hist(a)
plt.show()

# %%
data1 = np.random.normal(0,1,20)
data2 = np.random.normal(1,2,10)

# %%
plt.hist([data1,data2],color = ['r','b'],bins = 20,label = ['Hist1','Hist2'])
plt.legend()
plt.show()

# %%
x2 = np.random.randn(10)
y2 = np.random.randn(10)

# %%
#scatter plot --> if we want to understand the relationship b/w two feature then we have to visualize using scatter plot
x2 = np.random.randn(10)
y2 = np.random.randn(10)

plt.scatter(x2,y2,c = 'g')

# %%
plt.scatter(x2,y2,c = 'r', marker = '*')
plt.show()

# %%
#bar plot
x = ['A','B','C','D','E']
y = [10,20,30,40,50]

plt.bar(x,y,color = 'm')
plt.show()
