# %%
f = open("Shiva.txt", "w")
print(f)
# Out:
# <_io.TextIOWrapper name='Shiva.txt' mode='w' encoding='UTF-8'>

# %%
f.write('hello this is my first line')
# Out:
# 27

# %%
f.close()

# %%
f = open("Shiva.txt", "r")

# %%
f.name
# Out:
# 'Shiva.txt'

# %%
f.mode
# Out:
# 'r'

# %%
for i in f:
    print(i)
# Out:
# hello this is my first line

# %%
f.close()

# %%
f.closed #file is open
# Out:
# True

# %%
f = open("Shiva.txt", "r")
print(f.read())
# Out:
# hello this is my first line

# %%
import os

# %%
os.getcwd()
# Out:
# '/Users/sangameshwaruppe/Intellipat_Handson/Datascience_Project_2026'

# %%
ls
# Out:
# Files.ipynb  geek.txt     Shiva.txt

# %%
os.mkdir('test')

# %%
os.makedirs('tst/tst1')

# %%
os.listdir()
# Out:
# ['test',
#  'geek.txt',
#  'Shiva.txt',
#  'Files.ipynb',
#  '.ipynb_checkpoints',
#  'tst',
#  '.git']

# %%
os.rmdir('test')

# %%
import shutil as st

# %%
st.rmtree('tst')

# %%
with open("Shiva.txt", "a") as f:
    f.write('\nhello this is my 2nd line')

# %%
f = open("geek.txt", "r")
print(f.read())
# Out:
# hello this is my first line
# hello

# %%
##################

# %%
try:
    open("example.txt",'r')
    
except Exception as e:
    print('there is an issue while opening the file',e)
print("\nthis is next line of code")
print(9+12)
# Out:
# there is an issue while opening the file [Errno 2] No such file or directory: 'example.txt'
#
# this is next line of code
# 21

# %%
try:
    print(5/0)
except Exception as e:
    print(e)
print(9+10)
print(1/2)
# Out:
# division by zero
# 19
# 0.5

# %%
try:
    open("Shiva.txt",'r')
except Exception as e:
    print('there is an issue while opening the file',e)
else:
    print("this is excuted becz file is exists")
print(9+12)
# Out:
# this is excuted becz file is exists
# 21

# %%
try:
    open("Shiva1.txt",'r')
except Exception as e:
    print('there is an issue while opening the file',e)
else:
    print("this is excuted becz file is exists")
print(9+12)
# Out:
# there is an issue while opening the file [Errno 2] No such file or directory: 'Shiva1.txt'
# 21

# %%
try:
    f = open("Shivanand.txt",'w')
    f.write("Hello this is my writer file")
except Exception as e:
    print("there is an issue while trying to open the file in write mode",e)
else:
    f.close()
    print(5+3)
    print("this is excuted if try block didnt throw any exception")
finally:
    print("this will be excuted always")
# Out:
# 8
# this is excuted if try block didnt throw any exception
# this will be excuted always

# %%
try:
    f = open("Shivanand1.txt",'r')
    f.write("Hello this is my writer file")
except Exception as e:
    print("there is an issue while trying to open the file in write mode",e)
else:
    f.close()
    print(5+3)
    print("this is excuted if try block didnt throw any exception")
finally:
    print("this will be excuted always")
# Out:
# there is an issue while trying to open the file in write mode [Errno 2] No such file or directory: 'Shivanand1.txt'
# this will be excuted always

# %%
def validate_salary(salary):
    if salary < 0:
        print("negative salary is not possible")
    elif salary > 30000000:
        print("salary is unexpcted")
    else:
        print('salary is valid')
#usuage :
validate_salary(100000)
# Out:
# salary is valid

# %%
class validatesalary(Exception):
    def __init__(self,msg):
        self.msg = msg

# %%
def validate_salary(salary):
    if salary < 0:
        raise validatesalary("negative salary is not possible")
    elif salary > 30000000:
        raise validatesalary("salary is unexpcted")
    else:
       raise validatesalary('salary is valid')

# %%
try :
    salary = int(input("Enter the salary:"))
    validate_salary(salary)
except Exception as e:
    print(e)
# Out:
# Enter the salary: 9090909090909090
# salary is unexpcted
